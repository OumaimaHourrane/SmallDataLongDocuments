# %% [markdown]
# # Data Exploration v0

# %%
import os
import sys
sys.path.insert(0, os.path.abspath(os.path.join('..', 'src')))
import visualize as vis

import pandas as pd
import pickle

# %%
'''Import data'''
with open(os.path.abspath(os.path.join('..', 'data/interim'))+'/description.pkl', 'rb') as handle:
    description = pickle.load(handle)

# %%
vis.draw_cloud(description, 'project_description')
# Out:
# <PIL.Image.Image image mode=RGB size=400x200 at 0x10A0A9970>

# %%
# Out:
# pandas.core.series.Series
